-- %%
CREATE TABLE IF NOT EXISTS northwind.bronze.customers
USING DELTA
LOCATION 'abfss://bronze@nwpipelined.dfs.core.windows.net/customers/';

CREATE TABLE IF NOT EXISTS northwind.bronze.orders
USING DELTA
LOCATION 'abfss://bronze@nwpipelined.dfs.core.windows.net/orders/';

CREATE TABLE IF NOT EXISTS northwind.bronze.products
USING DELTA
LOCATION 'abfss://bronze@nwpipelined.dfs.core.windows.net/products/';
